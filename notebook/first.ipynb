# %% [markdown]
# Meu primeiro notebook

# %%
from google.colab import ai

response = ai.generate_text("Oi, se eu sou homem e não tenho irmãos, quem é o filho do meu pai?")
print(response)
# Out:
# É você!
#
# Se você é homem e não tem irmãos, então você é o único filho do seu pai.
